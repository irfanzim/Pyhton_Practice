# %% [markdown]
# <h2 align="center" style="color:blue">List, Dict Comprehension Tutorial</h2>

# %%
numbers = [1,2,3,4,5]

# %% [markdown]
# #### Using For loop create a list of squared numbers

# %% [markdown]
# #### Using list comprehension do the same

# %% [markdown]
# ### List Comprehension With Two Lists

# %%
price = [100,120,80,50]
earning_per_share = [9, 15, 40, 2]

# %% [markdown]
# #### create a list of pe (price/eps)

# %% [markdown]
# ### what if in eps one value is 0
# for instance:
#
# price = [100,120,80,50]
#
# earning_per_share = [9, 15, 0, 2]

# %% [markdown]
# ### Calling a Function in List Comprehension

# %%
words = ["apple", "banana", "cherry", "date"]

# %% [markdown]
# #### Create a list of length of word in words

# %% [markdown]
# ### You are given a list of prices
#
# prices = [120, 99, 150, 80, 200]
#
# if prices are greater than 100 then it will automatically get 10% discount
#
# Now get the new price list

# %% [markdown]
# ### Dictionary Comprehension

# %%
names = ["Alice", "Bob", "Charlie"]
ages = [25, 30, 35]

# %% [markdown]
# #### Create a names:age dictionary using length method

# %% [markdown]
# #### Create a names:age dictionary using zip

# %% [markdown]
# ### Create a names:age dictionary using dict/zip

# %% [markdown]
# ### Set Comprehension

# %%
transactions = [
    {'customer_name': "Mira", "amount": 56, "date": "2024-08-01"},
    {'customer_name': "Mira", "amount": 12.3, "date": "2024-09-05"},
    {'customer_name': "Mohan", "amount": 21, "date": "2024-09-03"},
    {'customer_name': "Mohan", "amount": 36.8, "date": "2024-09-10"},
    {'customer_name': "Lucy", "amount": 66.3, "date": "2024-09-10"}
]

# %% [markdown]
# ### Get unique customer list using set comprehension
